# %%
import numpy as np

# %%
def pretty_print(ideal):
    for eq in ideal.gens():
        print(eq)

# %%
class VectorOfMatrices:
    def __init__(self, matrices):
        self.matrices = matrices
        self.len = len(matrices)

    def get_len(self):
        return self.len
     
    def __mul__(self, other):
        # https://doc.sagemath.org/html/en/reference/matrices/sage/matrix/matrix_dense.html
        if not isinstance(other, sage.matrix.matrix_dense.Matrix_dense):
            raise TypeError("We only multiply by a matrix my dear")

        if other.ncols() != self.len:
            raise ValueError("Matrix dimensions do not match")

        # multiply them by hand
        result = [sum(other[i, j] * self.matrices[j] for j in range(self.len)) for i in range(other.nrows())]
        # gives back a list
        return result

    def __sub__(self, other):
        # https://doc.sagemath.org/html/en/reference/modules/sage/modules/vector_modn_dense.html#sage.modules.vector_modn_dense.Vector_modn_dense
        # if not isinstance(other, sage.modules.vector_modn_dense):
            # raise TypeError("We only subtract other VectorOfMatrices my dear")

        if other.len != self.len:
            raise ValueError("Vector dimensions do not match")

        result = [self.matrices[i] - other.matrices[i] for i in range(self.len)]
        return result
        
    def __repr__(self):
        return f"VectorOfMatrices(\n{self.matrices})"
    
    __rmul__ = __mul__
    __rsub__ = __sub__

# %%
class Instance:
    def __init__(self, n, m, p):
        self.n = n
        self.m = m
        self.size = p
        self.field = GF(p)

        self.R = PolynomialRing(self.field, n^2 + m^2, 'x')
        self.R.inject_variables(verbose=False)
        
        self.F = []
        self.S = np.zeros((self.n, self.n), dtype=int)
        self.T = np.zeros((self.m, self.m), dtype=int)
        
        self.P = []

        # print("--------------------------------------------------------------------------------------------------")
        # print(f"| An instance of inhQMLE over Finite Field with {self.size} elements, n = {self.n} variables and m = {self.m} equations. |")
        # print("--------------------------------------------------------------------------------------------------")

    def populate(self):
        self.generate_private()
        self.generate_public()
        
    def _random_symmetric_matrix(self):
        # get a random matrix
        A = random_matrix(self.field, self.n, self.n)
        # and make it symmetric
        return A + A.transpose()

    def _random_polynomial(self):
        return self._random_symmetric_matrix(), random_vector(self.field, self.n), self.field.random_element()

    def generate_private(self):
        self.T = matrix(GL(self.m, self.field).random_element())
        self.S = matrix(GL(self.n, self.field).random_element())
        if self.F == []:
            # print(f"Generating random polynomials over a finite field with {self.size} elements")
            self.F = [[],[],[]]
            for i in range(m):
                A, B, C = self._random_polynomial()
                self.F[0].append(A)
                self.F[1].append(B)
                self.F[2].append(C)
    
    def show_private(self):
        print(f"The input transformation S\n{self.S}")
        print(f"The output transformation T\n{self.T}")
        print("The central map F[i](x) = x^T A[i]x + b[i]x + c[i]")
        for i in range(m):
            print(f"F[{i}]:Matrix\n{self.F[0][i]}, Vector {self.F[1][i]}, Scalar {self.F[2][i]}\n---------------------------------------------")

    def generate_public(self):
        if self.P == []:
            self.P = [[],[],[]]
            v = VectorOfMatrices([self.S.transpose()*A*self.S for A in self.F[0]])
            self.P = [self.T*v, self.T*matrix([B*self.S for B in self.F[1]]), self.T*vector(self.F[2])]

    def show_public(self):
        print("The public set of polynomials P[i](x) = sum_{j=1}^m t_{i,j} f^{(j)}(Sx)")
        for i in range(m):
            print(f"P[{i}]: Matrix\n{self.P[0][i]}, Vector {self.P[1][i]}, Scalar {self.P[2][i]}\n---------------------------------------------")

    def model(self):
        gens = self.R.gens()

        # first n^2 elements of R2
        S_ = matrix(self.R, self.n, self.n, gens[:self.n^2])

        # we get the last m^2 variables of R2
        T_ = matrix(self.R, self.m, self.m, gens[-self.m^2:])

        auxiliary = [[],[],[]]
        
        auxiliary0 = T_*VectorOfMatrices(self.P[0])
        Q0 = VectorOfMatrices([S_.transpose()*A*S_ for A in self.F[0]])
        
        auxiliary1 = T_*self.P[1]
        Q1 = matrix([B*S_ for B in self.F[1]])
        
        auxiliary2 = T_*self.P[2]
        Q2 = vector(self.F[2])
        
        # add the field equations by hand
        system = [x^self.size - x for x in gens]
        M = VectorOfMatrices(auxiliary0) - Q0
        for i in range(m):
            system += M[i].list()
            system += (auxiliary1[i] - Q1[i]).list()
            system += [auxiliary2[i] - Q2[i]]
        
        # the list(set(.)) removes the duplicates
        return self.R.ideal(list(set(system)))

    # given a system of polynomials, check if it correctly corresponds
    # to the actual matrices it was created from
    #
    # ideal is an ideal of multivariate polynomial ring defined above
    def is_ideal_correct(self, ideal):

        # point = self.S.list() + matrix(GL(self.m, self.field).random_element()).list()
        point = self.S.list() + self.T.inverse().list()
        # point = self.S.list()+self.T.list()
    
        gens = self.R.gens()
        # make an appropriate dict
        substitution_dict = {gens[i]: point[i] for i in range(len(point))}
        
        return all(f.subs(substitution_dict) == 0 for f in ideal.gens())


    # i think this is wrong as the variety might have many points but 
    # we are only interested in the point corresponding to S and T
    def is_variety_correct(self, variety):
        point = self.S.list() + self.T.inverse().list()
        gens = self.R.gens()

        return all(variety[j][var] == point[i] for i, var in enumerate(gens) for j in range(len(variety)))
        # return all(f.subs(substitution_dict) == 0 for f in ideal.gens())

# %%
p = 101
n = 4
m = 3

inst = Instance(n, m, p)
inst.populate()
# inst.generate_private()
# inst.show_private()

# inst.generate_public()
# inst.show_public()

I = inst.model()
print(I)
print(inst.is_ideal_correct(I))
print(I.groebner_basis())
# %timeit I.groebner_basis()
# %timeit I.variety()
# for i in range(len(V)):
    # print(V[i])

# pt = inst.S.list() + inst.T.inverse().list()
# print(len(pt))
# for i, var in enumerate(inst.R.gens()):
#     if V[0][var] != pt[i]:
#         print(False)
    
# print(inst.is_variety_correct(V))
# Out:
# Ideal (-45*x19 + 9*x20 + 42*x21 + 50, 30*x0*x3 - 8*x3*x4 - 8*x0*x7 + 40*x4*x7 - 28*x3*x8 - 45*x7*x8 - 28*x0*x11 - 45*x4*x11 - 4*x8*x11 - 22*x3*x12 + 31*x7*x12 - 27*x11*x12 - 22*x0*x15 + 31*x4*x15 - 27*x8*x15 - x12*x15 - 46*x19 - 46*x20 + 50*x21, 30*x2*x3 - 8*x3*x6 - 8*x2*x7 + 40*x6*x7 - 28*x3*x10 - 45*x7*x10 - 28*x2*x11 - 45*x6*x11 - 4*x10*x11 - 22*x3*x14 + 31*x7*x14 - 27*x11*x14 - 22*x2*x15 + 31*x6*x15 - 27*x10*x15 - x14*x15 + 41*x19 + 44*x20 + 14*x21, -10*x1*x3 + 3*x3*x5 + 3*x1*x7 - 8*x5*x7 + 10*x3*x9 + 34*x7*x9 + 10*x1*x11 + 34*x5*x11 + 33*x9*x11 + 23*x3*x13 + 25*x7*x13 - 42*x11*x13 + 23*x1*x15 + 25*x5*x15 - 42*x9*x15 - 2*x13*x15 + 22*x16 - 2*x17 + 12*x18, x8^101 - x8, x11^101 - x11, x18^101 - x18, x22^101 - x22, -10*x3^2 + 6*x3*x7 - 8*x7^2 + 20*x3*x11 - 33*x7*x11 + 33*x11^2 + 46*x3*x15 + 50*x7*x15 + 17*x11*x15 - 2*x15^2 + 34*x16 + 19*x17 + 12*x18, x1^101 - x1, x9^101 - x9, x10^101 - x10, x20^101 - x20, -16*x2*x3 - 20*x3*x6 - 20*x2*x7 + 24*x6*x7 + 30*x3*x10 + 27*x7*x10 + 30*x2*x11 + 27*x6*x11 - 44*x10*x11 - 30*x3*x14 - 32*x7*x14 - 4*x11*x14 - 30*x2*x15 - 32*x6*x15 - 4*x10*x15 - 47*x14*x15 + 41*x22 + 44*x23 + 14*x24, -45*x22 + 9*x23 + 42*x24 - 5, 31*x2 + 27*x6 + 22*x10 + 43*x14 - 17*x19 - 33*x20 - 32*x21, 14*x3 + 2*x7 + 35*x11 + 24*x15 + 45*x16 + 48*x17 + 10*x18, -10*x0*x2 + 3*x2*x4 + 3*x0*x6 - 8*x4*x6 + 10*x2*x8 + 34*x6*x8 + 10*x0*x10 + 34*x4*x10 + 33*x8*x10 + 23*x2*x12 + 25*x6*x12 - 42*x10*x12 + 23*x0*x14 + 25*x4*x14 - 42*x8*x14 - 2*x12*x14 - 23*x16 - 11*x17 - 37*x18, 30*x1*x3 - 8*x3*x5 - 8*x1*x7 + 40*x5*x7 - 28*x3*x9 - 45*x7*x9 - 28*x1*x11 - 45*x5*x11 - 4*x9*x11 - 22*x3*x13 + 31*x7*x13 - 27*x11*x13 - 22*x1*x15 + 31*x5*x15 - 27*x9*x15 - x13*x15 + 22*x19 - 2*x20 + 12*x21, -16*x3^2 - 40*x3*x7 + 24*x7^2 - 41*x3*x11 - 47*x7*x11 - 44*x11^2 + 41*x3*x15 + 37*x7*x15 - 8*x11*x15 - 47*x15^2 + 34*x22 + 19*x23 + 12*x24, x3^101 - x3, x16^101 - x16, 30*x2^2 - 16*x2*x6 + 40*x6^2 + 45*x2*x10 + 11*x6*x10 - 4*x10^2 - 44*x2*x14 - 39*x6*x14 + 47*x10*x14 - x14^2 + 2*x19 + 30*x20 + 31*x21, 31*x0 + 27*x4 + 22*x8 + 43*x12 - 38*x19 + 10*x20 - 8*x21, 30*x0*x2 - 8*x2*x4 - 8*x0*x6 + 40*x4*x6 - 28*x2*x8 - 45*x6*x8 - 28*x0*x10 - 45*x4*x10 - 4*x8*x10 - 22*x2*x12 + 31*x6*x12 - 27*x10*x12 - 22*x0*x14 + 31*x4*x14 - 27*x8*x14 - x12*x14 - 23*x19 - 11*x20 - 37*x21, -10*x1*x2 + 3*x2*x5 + 3*x1*x6 - 8*x5*x6 + 10*x2*x9 + 34*x6*x9 + 10*x1*x10 + 34*x5*x10 + 33*x9*x10 + 23*x2*x13 + 25*x6*x13 - 42*x10*x13 + 23*x1*x14 + 25*x5*x14 - 42*x9*x14 - 2*x13*x14 - 30*x16 + 50*x17 + 24*x18, x13^101 - x13, x17^101 - x17, x19^101 - x19, x21^101 - x21, 14*x2 + 2*x6 + 35*x10 + 24*x14 - 17*x16 - 33*x17 - 32*x18, -10*x1^2 + 6*x1*x5 - 8*x5^2 + 20*x1*x9 - 33*x5*x9 + 33*x9^2 + 46*x1*x13 + 50*x5*x13 + 17*x9*x13 - 2*x13^2 + 23*x16 + 31*x17 + 36*x18, -16*x2^2 - 40*x2*x6 + 24*x6^2 - 41*x2*x10 - 47*x6*x10 - 44*x10^2 + 41*x2*x14 + 37*x6*x14 - 8*x10*x14 - 47*x14^2 + 2*x22 + 30*x23 + 31*x24, -16*x1*x2 - 20*x2*x5 - 20*x1*x6 + 24*x5*x6 + 30*x2*x9 + 27*x6*x9 + 30*x1*x10 + 27*x5*x10 - 44*x9*x10 - 30*x2*x13 - 32*x6*x13 - 4*x10*x13 - 30*x1*x14 - 32*x5*x14 - 4*x9*x14 - 47*x13*x14 - 30*x22 + 50*x23 + 24*x24, 48*x3 + 17*x7 + 40*x11 + 29*x15 + 45*x22 + 48*x23 + 10*x24, 30*x1*x2 - 8*x2*x5 - 8*x1*x6 + 40*x5*x6 - 28*x2*x9 - 45*x6*x9 - 28*x1*x10 - 45*x5*x10 - 4*x9*x10 - 22*x2*x13 + 31*x6*x13 - 27*x10*x13 - 22*x1*x14 + 31*x5*x14 - 27*x9*x14 - x13*x14 - 30*x19 + 50*x20 + 24*x21, 14*x1 + 2*x5 + 35*x9 + 24*x13 + 27*x16 - 8*x17 + 6*x18, x12^101 - x12, x23^101 - x23, -10*x2*x3 + 3*x3*x6 + 3*x2*x7 - 8*x6*x7 + 10*x3*x10 + 34*x7*x10 + 10*x2*x11 + 34*x6*x11 + 33*x10*x11 + 23*x3*x14 + 25*x7*x14 - 42*x11*x14 + 23*x2*x15 + 25*x6*x15 - 42*x10*x15 - 2*x14*x15 + 41*x16 + 44*x17 + 14*x18, 30*x1^2 - 16*x1*x5 + 40*x5^2 + 45*x1*x9 + 11*x5*x9 - 4*x9^2 - 44*x1*x13 - 39*x5*x13 + 47*x9*x13 - x13^2 + 23*x19 + 31*x20 + 36*x21, x5^101 - x5, x24^101 - x24, -10*x2^2 + 6*x2*x6 - 8*x6^2 + 20*x2*x10 - 33*x6*x10 + 33*x10^2 + 46*x2*x14 + 50*x6*x14 + 17*x10*x14 - 2*x14^2 + 2*x16 + 30*x17 + 31*x18, 31*x1 + 27*x5 + 22*x9 + 43*x13 + 27*x19 - 8*x ...
# True
# // ** redefining # (parameter def i_par; parameter list #;  ) standard.lib::groebner:830
# // ** redefining P (  def P=basering;) standard.lib::groebner:871
# // ** redefining i (ideal i=i_par; ) standard.lib::groebner:872
# // ** redefining method (  string method;                //all given methods as a coma separated string) standard.lib::groebner:883
# // ** redefining k (  int k;) standard.lib::groebner:884
# // ** redefining @Minpoly (  string @Minpoly = string(minpoly);      //minimal polynomial) standard.lib::groebner:894
# // ** redefining was_minpoly (  int was_minpoly;             //remembers if there was a minpoly in P) standard.lib::groebner:895
# // ** redefining Qideal (  ideal Qideal = ideal(P);      //defining the quotient ideal if P is a qring) standard.lib::groebner:901
# // ** redefining was_qring (  int was_qring;                //remembers if basering was a qring) standard.lib::groebner:902
# // ** redefining BRlist (  list BRlist = ring_list(P);     //ringlist of basering) standard.lib::groebner:909
# // ** redefining ord_P (  list ord_P = BRlist[3];       //should be available in all rings) standard.lib::groebner:912
# // ** redefining ordstr_P (  string ordstr_P = ordstr(P);) standard.lib::groebner:913
# // ** redefining nvars_P (  int nvars_P = nvars(P);) standard.lib::groebner:914
# // ** redefining npars_P (  int npars_P = npars(P);) standard.lib::groebner:915
# // ** redefining w (  intvec w;                     //for ringweights of basering P) standard.lib::groebner:916
# // ** redefining neg (  int neg=1-attrib (P,"global");) standard.lib::groebner:921
# // ** redefining opt (  intvec opt=option(get);) standard.lib::groebner:924
# // ** redefining s_opt (  string s_opt = option();) standard.lib::groebner:925
# // ** redefining p_opt (  int p_opt;) standard.lib::groebner:926
# // ** redefining algorithm (  string algorithm;       //possibilities: std, slimgb, stdorslimgb, mathicgb) standard.lib::groebner:947
# // ** redefining conversion (  string conversion;      //possibilities: hilb, fglm, hilborfglm, no) standard.lib::groebner:948
# // ** redefining partovar (  string partovar;        //possibilities: yes, no) standard.lib::groebner:949
# // ** redefining order (  string order;           //possibilities: simple, !simple) standard.lib::groebner:950
# // ** redefining direct (  string direct;          //possibilities: yes, no) standard.lib::groebner:951
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/sage/misc/cachefunc.pyx:1953, in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:13472)()
#    1952 try:
# -> 1953     return cache[k]
#    1954 except TypeError:  # k is not hashable
#
# KeyError: (('', None, None, False), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[218], line 16
#      14 print(I)
#      15 print(inst.is_ideal_correct(I))
# ---> 16 print(I.groebner_basis())
#      17 # %timeit I.groebner_basis()
#      18 # %timeit I.variety()
#      19 # for i in range(len(V)):
#    (...)
#      27
#      28 # print(inst.is_variety_correct(V))
#
# File /usr/lib/python3.13/site-packages/sage/misc/cachefunc.pyx:1958, in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:13608)()
#    1956         return cache[k]
#    1957 except KeyError:
# -> 1958     w = self._instance_call(*args, **kwds)
#    1959     cache[k] = w
#    1960     return w
#
# File /usr/lib/python3.13/site-packages/sage/misc/cachefunc.pyx:1834, in sage.misc.cachefunc.CachedMethodCaller._instance_call (build/cythonized/sage/misc/cachefunc.c:13056)()
#    1832         True
#    1833     """
# -> 1834     return self.f(self._instance, *args, **kwds)
#    1835
#    1836 cdef fix_args_kwds(self, tuple args, dict kwds):
#
# File /usr/lib/python3.13/site-packages/sage/rings/qqbar_decorators.py:98, in handle_AA_and_QQbar.<locals>.wrapper(*args, **kwds)
#      92 from sage.rings.abc import AlgebraicField_common
#      94 if not any(isinstance(a, (Polynomial, MPolynomial, Ideal_generic))
#      95            and isinstance(a.base_ring(), AlgebraicField_common)
#      96            or isinstance(a, PolynomialSequence_generic)
#      97            and isinstance(a.ring().base_ring(), AlgebraicField_common) for a in args):
# ---> 98     return func(*args, **kwds)
#     100 polynomials = []
#     102 for a in flatten(args, ltypes=(list, tuple, set)):
#
# File /usr/lib/python3.13/site-packages/sage/rings/polynomial/multi_polynomial_ideal.py:4684, in MPolynomialIdeal.groebner_basis(self, algorithm, deg_bound, mult_bound, prot, *args, **kwds)
#    4682 if not algorithm:
#    4683     try:
# -> 4684         gb = self._groebner_basis_libsingular("groebner", deg_bound=deg_bound, mult_bound=mult_bound, *args, **kwds)
#    4685     except (TypeError, NameError, ImportError):  # conversion to Singular not supported
#    4686         try:
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/standard_options.py:141, in libsingular_gb_standard_options.<locals>.wrapper(*args, **kwds)
#     137 """
#     138 Execute function in ``LibSingularGBDefaultContext``.
#     139 """
#     140 with LibSingularGBDefaultContext():
# --> 141     return func(*args, **kwds)
#
# File /usr/lib/python3.13/site-packages/sage/rings/polynomial/multi_polynomial_ideal.py:559, in MPolynomialIdeal_singular_base_repr._groebner_basis_libsingular(self, algorithm, *args, **kwds)
#     557     S = slimgb_libsingular(self)
#     558 elif algorithm == "groebner":
# --> 559     S = groebner(self)
#     560 else:
#     561     try:
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/function.pyx:1309, in sage.libs.singular.function.SingularFunction.__call__ (build/cythonized/sage/libs/singular/function.cpp:21539)()
#    1307     if not (isinstance(ring, MPolynomialRing_libsingular) or isinstance(ring, NCPolynomialRing_plural)):
#    1308         raise TypeError("cannot call Singular function '%s' with ring parameter of type '%s'" % (self._name,type(ring)))
# -> 1309     return call_function(self, args, ring, interruptible, attributes)
#    1310
#    1311 def _instancedoc_(self):
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/function.pyx:1482, in sage.libs.singular.function.call_function (build/cythonized/sage/libs/singular/function.cpp:23332)()
#    1480     error_messages.pop()
#    1481
# -> 1482 with opt_ctx: # we are preserving the global options state here
#    1483     if signal_handler:
#    1484         sig_on()
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/function.pyx:1484, in sage.libs.singular.function.call_function (build/cythonized/sage/libs/singular/function.cpp:23244)()
#    1482 with opt_ctx: # we are preserving the global options state here
#    1483     if signal_handler:
# -> 1484         sig_on()
#    1485         _res = self.call_handler.handle_call(argument_list, si_ring)
#    1486         sig_off()
#
# KeyboardInterrupt:

# %%
primes = Primes()
p = primes.next(2)

i = 0
n = 5
m = 4

while (i < 5):
    i+=1
    inst = Instance(n, m, p)
    inst.populate()
    I = inst.model()
    if not inst.is_ideal_correct(I):
        print("oh nooooooo")

    print(timeit.eval("I.groebner_basis()"))
    inst = Instance(n, m, p^2)
    inst.populate()
    I = inst.model()
    if not inst.is_ideal_correct(I):
        print("oh nooooooo")

    print(timeit.eval("I.groebner_basis()"))
    
    inst = Instance(n, m, p^3)
    inst.populate()
    I = inst.model()
    if not inst.is_ideal_correct(I):
        print("oh nooooooo")

    print(timeit.eval("I.groebner_basis()"))
# Out:
# 625 loops, best of 3: 293 ns per loop
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/sage/misc/cachefunc.pyx:1953, in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:13472)()
#    1952 try:
# -> 1953     return cache[k]
#    1954 except TypeError:  # k is not hashable
#
# KeyError: (('', None, None, False), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[212], line 23
#      20 if not inst.is_ideal_correct(I):
#      21     print("oh nooooooo")
# ---> 23 print(timeit.eval("I.groebner_basis()"))
#      25 inst = Instance(n, m, p**Integer(3))
#      26 inst.populate()
#
# File /usr/lib/python3.13/site-packages/sage/misc/sage_timeit_class.pyx:81, in sage.misc.sage_timeit_class.SageTimeit.eval (build/cythonized/sage/misc/sage_timeit_class.c:2658)()
#      79 if globs is None:
#      80     globs = globals()
# ---> 81 return sage_timeit.sage_timeit(code, globs, **kwds)
#
# File /usr/lib/python3.13/site-packages/sage/misc/sage_timeit.py:244, in sage_timeit(stmt, globals_dict, preparse, number, repeat, precision, seconds)
#     242     for i in range(1, 5):
#     243         number *= 5
# --> 244         if timer.timeit(number) >= 0.2:
#     245             break
#     247 series = [s / number for s in timer.repeat(repeat, number)]
#
# File /usr/lib/python3.13/timeit.py:180, in Timer.timeit(self, number)
#     178 gc.disable()
#     179 try:
# --> 180     timing = self.inner(it, self.timer)
#     181 finally:
#     182     if gcold:
#
# File <magic-timeit>:6, in inner(_it, _timer)
#
# File /usr/lib/python3.13/site-packages/sage/misc/cachefunc.pyx:1958, in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:13608)()
#    1956         return cache[k]
#    1957 except KeyError:
# -> 1958     w = self._instance_call(*args, **kwds)
#    1959     cache[k] = w
#    1960     return w
#
# File /usr/lib/python3.13/site-packages/sage/misc/cachefunc.pyx:1834, in sage.misc.cachefunc.CachedMethodCaller._instance_call (build/cythonized/sage/misc/cachefunc.c:13056)()
#    1832         True
#    1833     """
# -> 1834     return self.f(self._instance, *args, **kwds)
#    1835
#    1836 cdef fix_args_kwds(self, tuple args, dict kwds):
#
# File /usr/lib/python3.13/site-packages/sage/rings/qqbar_decorators.py:98, in handle_AA_and_QQbar.<locals>.wrapper(*args, **kwds)
#      92 from sage.rings.abc import AlgebraicField_common
#      94 if not any(isinstance(a, (Polynomial, MPolynomial, Ideal_generic))
#      95            and isinstance(a.base_ring(), AlgebraicField_common)
#      96            or isinstance(a, PolynomialSequence_generic)
#      97            and isinstance(a.ring().base_ring(), AlgebraicField_common) for a in args):
# ---> 98     return func(*args, **kwds)
#     100 polynomials = []
#     102 for a in flatten(args, ltypes=(list, tuple, set)):
#
# File /usr/lib/python3.13/site-packages/sage/rings/polynomial/multi_polynomial_ideal.py:4684, in MPolynomialIdeal.groebner_basis(self, algorithm, deg_bound, mult_bound, prot, *args, **kwds)
#    4682 if not algorithm:
#    4683     try:
# -> 4684         gb = self._groebner_basis_libsingular("groebner", deg_bound=deg_bound, mult_bound=mult_bound, *args, **kwds)
#    4685     except (TypeError, NameError, ImportError):  # conversion to Singular not supported
#    4686         try:
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/standard_options.py:141, in libsingular_gb_standard_options.<locals>.wrapper(*args, **kwds)
#     137 """
#     138 Execute function in ``LibSingularGBDefaultContext``.
#     139 """
#     140 with LibSingularGBDefaultContext():
# --> 141     return func(*args, **kwds)
#
# File /usr/lib/python3.13/site-packages/sage/rings/polynomial/multi_polynomial_ideal.py:559, in MPolynomialIdeal_singular_base_repr._groebner_basis_libsingular(self, algorithm, *args, **kwds)
#     557     S = slimgb_libsingular(self)
#     558 elif algorithm == "groebner":
# --> 559     S = groebner(self)
#     560 else:
#     561     try:
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/function.pyx:1309, in sage.libs.singular.function.SingularFunction.__call__ (build/cythonized/sage/libs/singular/function.cpp:21539)()
#    1307     if not (isinstance(ring, MPolynomialRing_libsingular) or isinstance(ring, NCPolynomialRing_plural)):
#    1308         raise TypeError("cannot call Singular function '%s' with ring parameter of type '%s'" % (self._name,type(ring)))
# -> 1309     return call_function(self, args, ring, interruptible, attributes)
#    1310
#    1311 def _instancedoc_(self):
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/function.pyx:1482, in sage.libs.singular.function.call_function (build/cythonized/sage/libs/singular/function.cpp:23332)()
#    1480     error_messages.pop()
#    1481
# -> 1482 with opt_ctx: # we are preserving the global options state here
#    1483     if signal_handler:
#    1484         sig_on()
#
# File /usr/lib/python3.13/site-packages/sage/libs/singular/function.pyx:1484, in sage.libs.singular.function.call_function (build/cythonized/sage/libs/singular/function.cpp:23244)()
#    1482 with opt_ctx: # we are preserving the global options state here
#    1483     if signal_handler:
# -> 1484         sig_on()
#    1485         _res = self.call_handler.handle_call(argument_list, si_ring)
#    1486         sig_off()
#
# KeyboardInterrupt:
